# %% [markdown]
# # Lab 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
sample = np.random.random(1000)
print("Shape:")
print(np.shape(sample))
print(f"Min = {np.min(sample)}")
print(f"Max = {np.max(sample)}")
print(f"Mean = {np.mean(sample)}")
print(f"Standard Deviation = {np.std(sample)}")
plt.hist(sample)
plt.show()
# Out:
# Shape:
# (1000,)
# Min = 0.000756001420013197
# Max = 0.9996796812153558
# Mean = 0.49290395559450373
# Standard Deviation = 0.28548027604217646

# %% [markdown]
# Distribution of Random Generated Numbers appears to be fairly uniform.

# %%
sample = np.random.normal(0, 1, 1000)
print("Shape:")
print(np.shape(sample))
print(f"Min = {np.min(sample)}")
print(f"Max = {np.max(sample)}")
print(f"Mean = {np.mean(sample)}")
print(f"Standard Deviation = {np.std(sample)}")
plt.hist(sample)
plt.show()
# Out:
# Shape:
# (1000,)
# Min = -3.1394200013784532
# Max = 3.3657478608872813
# Mean = 0.04371520766586685
# Standard Deviation = 1.0245934605582876

# %% [markdown]
# I believe that the parameters for random.normal are:
#
# random.normal(median/mean, standard deviation, sample size)

# %%
sample = np.random.normal(1, .2, 1000000)
print("Shape:")
print(np.shape(sample))
print(f"Min = {np.min(sample)}")
print(f"Max = {np.max(sample)}")
print(f"Mean = {np.mean(sample)}")
print(f"Standard Deviation = {np.std(sample)}")
plt.hist(sample, bins=100)
plt.show()
# Out:
# Shape:
# (1000000,)
# Min = 0.10734493199924766
# Max = 1.9354725665085177
# Mean = 1.000200444009159
# Standard Deviation = 0.1998250707389626

# %%
sample2 = np.random.random(1000)

plt.plot(sample2)
plt.ylim(0, 10)
plt.show()

# %%
sample2 = np.random.randint(0, 5, 1000)

plt.plot(sample2)
plt.ylim(0, 10)
plt.show()

# %% [markdown]
# randint(lower[inclusive], upper[exclusive], sample size)

# %%
sample2 = np.random.randint(0, 5, 15)

plt.plot(sample2)
plt.ylim(0, 10)
plt.show()

# %% [markdown]
# Plots the contents of the array on the y axis, with the index on the x axis. Then there is a direct slope that is drawn between the two points.

# %%
sample2 = np.random.randint(0, 5, [15, 2])
print(np.shape(sample2))
plt.ylim(0, 10)
plt.plot(sample2)
plt.show()
np.matrix(sample2)
# Out:
# (15, 2)
# matrix([[2, 3],
#         [1, 2],
#         [2, 1],
#         [2, 2],
#         [0, 0],
#         [4, 2],
#         [0, 0],
#         [1, 3],
#         [2, 0],
#         [0, 2],
#         [2, 1],
#         [4, 4],
#         [2, 1],
#         [1, 4],
#         [0, 1]])

# %%
plt.plot(sample2[:, 0], sample2[:, 1])
plt.show()

# %%
plt.plot(np.random.randint(1, 5, [15, 3]))
plt.ylim(0, 5)
# Out:
# (0.0, 5.0)

# %%
sample3 = np.random.randint(0, 5, [60, 2])
plt.ylim(0, 5)
plt.plot(sample3[:, 0], sample3[:, 1])
plt.savefig(f"graph{np.shape(sample3)}")
