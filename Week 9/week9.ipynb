# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
housing = pd.read_csv('housing.csv')
housing
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
plt.scatter(housing['area'], housing['price'])

x = np.linspace(0, 16000)
regression = slope * housing['area'] + intercept
plt.plot(housing['area'], regression, color='red')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Area vs Price of House')


plt.show()

# %%
slope, intercept, r, p, se = linregress(housing['area'], housing['price'])
result = linregress(housing['area'], housing['price'])
result
# Out:
# LinregressResult(slope=461.9748942727834, intercept=2387308.4823964303, rvalue=0.53599734577808, pvalue=7.388225401521766e-42, stderr=31.225635503291027, intercept_stderr=174497.79808379148)

# %%
p
# Out:
# 7.388225401521766e-42
