# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
vg_data = pd.read_csv("metacriticgames\Raw Data.csv")
vg_data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
vg_data_year = vg_data.groupby('Year_of_Release').count()['Name']
vg_data_year
# Out:
# Year_of_Release
# 1980.0       9
# 1981.0      46
# 1982.0      36
# 1983.0      17
# 1984.0      14
# 1985.0      14
# 1986.0      21
# 1987.0      16
# 1988.0      15
# 1989.0      17
# 1990.0      16
# 1991.0      41
# 1992.0      43
# 1993.0      60
# 1994.0     121
# 1995.0     219
# 1996.0     263
# 1997.0     289
# 1998.0     379
# 1999.0     338
# 2000.0     350
# 2001.0     482
# 2002.0     829
# 2003.0     775
# 2004.0     762
# 2005.0     939
# 2006.0    1006
# 2007.0    1197
# 2008.0    1427
# 2009.0    1426
# 2010.0    1255
# 2011.0    1136
# 2012.0     653
# 2013.0     544
# 2014.0     581
# 2015.0     606
# 2016.0     502
# 2017.0       3
# 2020.0       1
# Name: Name, dtype: int64

# %%
fig, ax = plt.subplots(1)
ax.plot(vg_data_year)
ax.set_xlabel("Year")
ax.set_ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
sorted_publishers[:10]
# Out:
# Publisher
# Electronic Arts                 1356
# Activision                       985
# Namco Bandai Games               939
# Ubisoft                          933
# Konami Digital Entertainment     834
# THQ                              715
# Nintendo                         706
# Sony Computer Entertainment      687
# Sega                             638
# Take-Two Interactive             422
# Name: Name, dtype: int64
